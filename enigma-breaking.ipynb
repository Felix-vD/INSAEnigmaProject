# %%
# !pip install py-enigma
# Out:
# Requirement already satisfied: py-enigma in c:\users\anwender\pycharmprojects\insaenigmaproject\venv\lib\site-packages (0.1)
# [notice] A new release of pip is available: 23.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from enigma.machine import EnigmaMachine

# %%
def find_all_cycles(graph, k = 3):
    def dfs(node, start_node, visited, path, all_cycles):
        path.append(node)
        visited[node] = True

        for neighbor in graph[node]:
            if neighbor == start_node and len(path) > 2:
                # Found circle: Copy current path and add it to the list
                all_cycles.append(path[:])
            elif neighbor not in visited or not visited[neighbor]:
                # Visit the neighbor who has not been visited yet
                dfs(neighbor, start_node, visited, path, all_cycles)

        # Backtrack: Remove current node from path and mark it as visited
        path.pop()
        visited[node] = False

    all_cycles = []
    visited = {node: False for node in graph}

    for start_node in graph:
        dfs(start_node, start_node, visited, [], all_cycles)
    

    # Remove duplicates
    unique_cycles = []
    seen = list()
    for cycle in all_cycles:
        cycle_set = set(cycle)
        if cycle_set not in seen:
            unique_cycles.append(cycle)
            seen.append(cycle_set)

    unique_cycles.sort(key=len, reverse=True)

    return unique_cycles[0: min(k, len(unique_cycles))]

# example graph
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'C', 'D'],
    'C': ['A', 'B', 'E'],
    'D': ['B', 'E'],
    'E': ['C', 'D']
}

graph = {'A': ['T', 'L', 'E', 'I'], 'B': [], 'C': ['E', 'T', 'E'], 'D': ['V', 'G'], 'E': ['C', 'X', 'M', 'A', 'X', 'T', 'C'], 'F': ['M'], 'G': ['S', 'H', 'D'], 'H': ['G'], 'I': ['Z', 'V', 'A', 'Q'], 'J': ['N', 'R'], 'K': [], 'L': ['A', 'R'], 'M': ['R', 'E', 'F'], 'N': ['J', 'V', 'R', 'R'], 'O': [], 'P': [], 'Q': ['I'], 'R': ['M', 'N', 'L', 'N', 'J'], 'S': ['G', 'U', 'Y'], 'T': ['Z', 'V', 'A', 'C', 'E'], 'U': ['S', 'X'], 'V': ['T', 'N', 'I', 'D'], 'W': [], 'X': ['E', 'E', 'U'], 'Y': ['S'], 'Z': ['T', 'I']}


# Suche nach allen Kreisen im Graphen
all_cycles = find_all_cycles(graph, 3)
print("Alle Kreise:")
for cycle in all_cycles:
    print(" -> ".join(cycle))
# Out:
# Alle Kreise:
# A -> L -> R -> J -> N -> V -> D -> G -> S -> U -> X -> E -> C -> T -> Z -> I
# A -> L -> R -> N -> V -> D -> G -> S -> U -> X -> E -> C -> T -> Z -> I
# A -> L -> R -> J -> N -> V -> D -> G -> S -> U -> X -> E -> T -> Z -> I

# %%
def format_plugboard(input_string: str) -> str:
    """
    Formats a plugboard configuration from a given string.
    
    - Removes connections with duplicate letters (e.g., 'VV').
    - Sorts the letters in each connection alphabetically (e.g., 'WV' -> 'VW').
    - Removes duplicate connections (e.g., 'IU' appearing twice).
    - Returns the valid connections as a string separated by spaces.
    
    :param input_string: A string with plug pairs, e.g., 'WA QQ FT UH ZG VV LM WW BN SE DR AA'.
    :return: A formatted string of valid connections, e.g., 'AW FT HU GZ LM BN DR'.
    """
    # Split the string into pairs
    pairs = input_string.split()
    
    # Set to store valid connections (Set automatically avoids duplicates)
    formatted_pairs = set()
    
    for pair in pairs:
        # Skip pairs with duplicate letters
        if pair[0] == pair[1]:
            continue
        
        # Sort the letters alphabetically and add the pair to the set
        formatted_pairs.add("".join(sorted(pair)))
    
    # Join the pairs with spaces and return the string
    return " ".join(sorted(formatted_pairs))  # Sort for consistent output


# Example call
input_string = "AS GH IU OP TZ IU ER DF"
formatted = format_plugboard(input_string)
print(formatted)  # Output: "AS DF ER GH IU OP TZ"
# Out:
# AS DF ER GH IU OP TZ

# %%
def check_and_merge_plugboards(plugboard1, plugboard2):
    """
    Checks if two plugboard configurations are compatible and creates a merged plugboard.

    :param plugboard1: First plugboard as a string (e.g., "AW FT HU GZ")
    :param plugboard2: Second plugboard as a string (e.g., "AW FT LM BN")
    :return: (True, merged_plugboard) if compatible, otherwise (False, "")
    """
    def parse_plugboard(plugboard):
        mapping = {}
        for pair in plugboard.split():
            if len(pair) == 2:
                a, b = sorted(pair)  # Ensure the smaller letter comes first
                mapping[a] = b
                mapping[b] = a
        return mapping

    # Parse the plugboards into mappings
    mapping1 = parse_plugboard(plugboard1)
    mapping2 = parse_plugboard(plugboard2)

    merged_mapping = {}

    # Check for compatibility
    for char in set(mapping1.keys()).union(mapping2.keys()):
        if char in mapping1 and char in mapping2:
            # If the character is in both mappings, the values must match
            if mapping1[char] != mapping2[char]:
                return False, ""  # Conflict found
            else:
                merged_mapping[char] = mapping1[char]
        elif char in mapping1:
            merged_mapping[char] = mapping1[char]
        elif char in mapping2:
            merged_mapping[char] = mapping2[char]

    # Check if the number of connections exceeds 10
    unique_pairs = {frozenset([k, v]) for k, v in merged_mapping.items()}
    if len(unique_pairs) > 10:
        return False, ""  # Too many connections

    # Create the merged plugboard as a string
    merged_plugboard = " ".join(f"{min(k, v)}{max(k, v)}" for k, v in merged_mapping.items() if k < v)

    return True, format_plugboard(merged_plugboard)


# Example calls
plugboard1 = "AW FH HU GZ"
plugboard2 = "AW FT LM BN"

is_compatible, merged = check_and_merge_plugboards(plugboard1, plugboard2)
if is_compatible:
    print("Compatible plugboards:", merged)
else:
    print("Plugboards are not compatible.")

print(check_and_merge_plugboards('AB CD EF GH IJ KL MN OP QR ST', 'AB'))
# Out:
# Plugboards are not compatible.
# (True, 'AB CD EF GH IJ KL MN OP QR ST')

# %%
def find_enigma_display_positions_to_index(rotor_string: str, plain_text: str, start_display:str):
    """This method determines the enigma display setting for every edge in the graph

    Args:
        rotor_string (str): 
        plain_text (str):
        start_display (str):

    Returns:
        array: contains the display settings for every edge
    """
    result_array = [""] * len(plain_text)
    enigma = EnigmaMachine.from_key_sheet(
        rotors=rotor_string,
        reflector='B',
        ring_settings="A A A",
        plugboard_settings='')
    enigma.set_display(start_display)
    for i in range(0, len(plain_text)): #iterate through every letter in the plain text := every edge in the graph
        result_array[i] = enigma.get_display()
        enigma.key_press('A')
    return result_array

find_enigma_display_positions_to_index('I II III', 'ABCDEFGHIJ', 'AEU')
# Out:
# ['AEU', 'BFV', 'BGW', 'BGX', 'BGY', 'BGZ', 'BGA', 'BGB', 'BGC', 'BGD']

# %%
def check_plugboard_configurations(config_param_list: list):
    """This method checks if the plugboard configurations from the turing-bombe run with the same settings but on different cycles are compatible
    Removes incompatible plugboard-configurations

    Args:
        config_param_list (list): list, containing a list for every cycle. This list (in the list) contains all the reconstructed plugboards for each cycle

    Returns:
        list: Reduces the list of lists to a list with only one list in it - the plugboard settings that are compatible with all the cycles
    """
    config_list = config_param_list
    if(len(config_list) < 1):
        return False, list()
    while(len(config_list) > 1):
        result_list = list()
        for i in range(0, len(config_list[0])): #iterate through all plugboards from first cycle
            for j in range(0, len(config_list[1])): #iterate through all plugboards from second cycle
                valid, merged_plugboard = check_and_merge_plugboards(config_list[0][i], config_list[1][j]) #check if they are compatible and merge them
                if valid:
                    result_list.append(format_plugboard(merged_plugboard))
                    #print('MERGED: ' + merged_plugboard)
        config_list[0] = result_list #set the result as the first list item
        config_list.pop(1) #remove the second list - whose information is now contained in the first list
        
    return len(config_list[0]) > 0, config_list


print(check_plugboard_configurations(list([list(['AB', 'CD']), list(['EF'])])))
print(check_plugboard_configurations(list([list(['AB', 'AF']), list(['EF', 'AG'])])))
print(check_plugboard_configurations(list([list(['AB', 'AF']), list(['AF', 'AG'])])))
print(check_plugboard_configurations(list([list(['AB', 'AF']), list(['AG'])])))
print(check_plugboard_configurations(list([list(['AB', 'AF']), list()])))
print(check_plugboard_configurations(list([list()])))
# Out:
# (True, [['AB EF', 'CD EF']])
# (True, [['AB EF']])
# (True, [['AF']])
# (False, [[]])
# (False, [[]])
# (False, [[]])

# %%
from itertools import combinations
from itertools import permutations

alphabet = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')

def filter_permutations(permutations_list):
    """This method used by the method brute forcing the remaining plugboard filters out all duplicate versions of additional plugboard connections

    Args:
        permutations_list (list): list of permutations

    Returns:
        list: reduced list of permutations
    """
    return [perm for perm in permutations_list if format_plugboard(concatenate_with_spaces(perm)) == concatenate_with_spaces(perm)]

def concatenate_with_spaces(letters):
    # concatenate letters from list and add a space after every second letter
    result = "".join(
        letter + (" " if (i + 1) % 2 == 0 and i + 1 != len(letters) else "")
        for i, letter in enumerate(letters)
    )
    return result


def brute_force_remaining_plugboard(config: dict, cypher_text:str, plain_text:str):
    """This method tries out all remaining possibilities for the plugboard connections, based on what we found out from the loop structures

    Args:
        config (dict): dictionary containing all the found out parameters for this configuration
        cypher_text (str): the cypher_text
        plain_text (str): the plain text
    """
    plugboard_without_spaces = config['plugboard'].replace(" ", "")
    if(len(plugboard_without_spaces) < 12): 
        return #prevents kernel from crashing because of too many options
    unplugged_letters = [item for item in alphabet if not item in list(plugboard_without_spaces)]
    all_combinations = list(combinations(unplugged_letters, 20 - len(plugboard_without_spaces)))
    for combination in all_combinations:
        relevant_permutations = filter_permutations(list(permutations(combination)))
        for permutation in relevant_permutations: #try out all combinations and permutations of the remaining letters as plugboard connections
            try_out_plugboard = check_and_merge_plugboards(concatenate_with_spaces(permutation), config['plugboard'])[1]
            decypher_enigma = EnigmaMachine.from_key_sheet( #set up an engima for testing
                    rotors=config['rotors'],
                    reflector='B',
                    ring_settings=config['ring-settings'],
                    plugboard_settings=try_out_plugboard)
            decypher_enigma.set_display(config['display'])
            decyphered_text = decypher_enigma.process_text(cypher_text) #try to decypher the cypher_text
            if(decyphered_text == plain_text):
                print('-----------------------------------------------------------------------------------------------------------')
                print('FOUND SOLUTION! - decyphered text: ' + decyphered_text)
                config['plugboard'] = try_out_plugboard
                print(config)
                print('-----------------------------------------------------------------------------------------------------------')
                return True
    print('--invalid configuration : ' + decyphered_text + ' config_plugboard: ' + config['plugboard'])


                    
        

brute_force_remaining_plugboard({'display': 'ABC', 'plugboard': 'CX EI FT MR NZ', 'rotors': 'I II III', 'ring-settings': 'A A A'}, 'SSZCJVTHRXZVRLEAVYC', 'GUTENTAGMEINNAMEIST')
#heuristic_determination_of_remaining_plugboard({'plugboards' : list(['CX EI FT LS MR NZ UW QY']), 'rotors':'I II III', 'ring-settings':'A A A', 'display':'PSY'}, 'AAKFOWKHUABKEQXNMKLJXHUTIWNLXZE', 'GUTENTAGMEINNAMEISTMAXRUEDINGER')

# %%
alphabet = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')

def find_identifier(a: str, b: str):
    """This method determines the identifier for an edge (necessary, since AB and BA represent the same edge)

    Args:
        a (str): the first node of an edge
        b (str): the second node of an edge

    Returns:
        str: the identifier for the edge (nodes sorted in alphabetical order)
    """
    if(alphabet.index(a) < alphabet.index(b)):
        token = a + b
    else:
        token = b + a
    return token

def hamming_distance(str1, str2):
    """
    Calculates the Hamming distance between two strings.
    
    :param str1: First string
    :param str2: Second string
    :return: Hamming distance
    """
    
    # Count the number of differing characters using a generator expression
    return sum(char1 != char2 for char1, char2 in zip(str1, str2))


def calc_hammingdistance_from_config(config: dict, crib:str, plain_text:str):
    decypher_enigma = EnigmaMachine.from_key_sheet( #set up an engima for testing
        rotors=config['rotors'],
        reflector='B',
        ring_settings=config['ring-settings'],
        plugboard_settings=config['plugboard'])
    decypher_enigma.set_display(config['display'])
    decyphered_text = decypher_enigma.process_text(crib)
    return hamming_distance(decyphered_text, plain_text)

# Example usage
str1 = "1011101"
str2 = "1001001"
print(f"Hamming distance: {hamming_distance(str1, str2)}")
# Out:
# Hamming distance: 2

# %%
def parse_steckerbrett(configuration):
    """
    Parses an Enigma plugboard configuration into a dictionary.
    
    :param configuration: A string representing the plugboard configuration (e.g., 'BO CI HT KY LP NU')
    :return: A dictionary mapping each letter to its paired letter
    """
    # Split the configuration into pairs
    pairs = configuration.split()
    
    # Create a dictionary for the mapping
    plugboard_mapping = {}
    
    for pair in pairs:
        # Map each letter to its counterpart
        plugboard_mapping[pair[0]] = pair[1]
        plugboard_mapping[pair[1]] = pair[0]
    
    return plugboard_mapping

# Example usage
config = 'BO CI HT KY LP NU'
plugboard = parse_steckerbrett(config)

print(f"Plugboard configuration: {plugboard}")

def create_plugboard_from_dict(mapping):
    """
    Converts a plugboard mapping dictionary back into a plugboard configuration string.
    
    :param mapping: A dictionary where each letter maps to its paired letter
    :return: A string representing the plugboard configuration (e.g., 'BO CI HT KY LP NU')
    """
    seen = set()  # To keep track of already processed letters
    pairs = []    # To store the pairs for the configuration string

    for key, value in mapping.items():
        # Ensure each pair is processed only once
        if key not in seen and value not in seen:
            pairs.append(f"{key}{value}")
            seen.add(key)
            seen.add(value)
    
    # Join the pairs with spaces to form the plugboard string
    return " ".join(pairs)

# Example usage
plugboard_mapping = {
    'B': 'O', 'O': 'B', 'C': 'I', 'I': 'C', 
    'H': 'T', 'T': 'H', 'K': 'Y', 'Y': 'K', 
    'L': 'P', 'P': 'L', 'N': 'U', 'U': 'N'
}

steckerbrett_string = create_plugboard_from_dict(plugboard_mapping)

print(f"Steckerbrett configuration: {steckerbrett_string}")
# Out:
# Plugboard configuration: {'B': 'O', 'O': 'B', 'C': 'I', 'I': 'C', 'H': 'T', 'T': 'H', 'K': 'Y', 'Y': 'K', 'L': 'P', 'P': 'L', 'N': 'U', 'U': 'N'}
# Steckerbrett configuration: BO CI HT KY LP NU

# %%
from collections import deque
def reconstruct_plugboard(index_dict: dict, graph, rotor_string: str, start_display: str, start_letter:str, ring_settings: str, start_plugboard: str, enigma_settings_array, plain_text: str, cypher_text:str):
    cypher_text_list = list(cypher_text)
    current_plugboard = start_plugboard
    decypher_enigma = EnigmaMachine.from_key_sheet( #set up an engima for testing
        rotors=rotor_string,
        reflector='B',
        ring_settings=ring_settings,
        plugboard_settings=current_plugboard)
    plain_text_list = list(plain_text)
    
    visited = set()  # To track visited nodes
    queue = deque([start_letter])  # Queue for BFS (starting with the start node)
    plugged_letters = parse_steckerbrett(start_plugboard)
    unplugged_letters = set()
    

    while queue:
        current = queue.popleft()  # Dequeue the next node
        if current not in visited:
            visited.add(current)  # Mark the node as visited
            # Add unvisited neighbors to the queue
            decypher_enigma.set_display(start_display)
            for neighbor in graph.get(current, []): #iterate through all neighbors = all incident edges
                #set enigma display to correct position for edge (if there are multiple edges between two nodes, choose the first one)
                decypher_enigma.set_display(enigma_settings_array[index_dict[find_identifier(current, neighbor)][0]]) 
                resulting_char = decypher_enigma.process_text(current)
                plain_text_char = plain_text_list[index_dict[find_identifier(current, neighbor)][0]]
                cypher_text_char = cypher_text_list[index_dict[find_identifier(current, neighbor)][0]]
                
                expected_char = plain_text_char if current != plain_text_char else cypher_text_char
                
                if(resulting_char == expected_char and not resulting_char in plugged_letters):
                    unplugged_letters.add(resulting_char) #character must be unplugged
                elif(resulting_char != expected_char and not resulting_char in plugged_letters):
                    plugged_letters[resulting_char] = expected_char #add plug...
                    plugged_letters[expected_char] = resulting_char #...in both directions
                    if(len(plugged_letters) > 20):
                        return False, ""
                    current_plugboard = create_plugboard_from_dict(plugged_letters)
                    decypher_enigma = EnigmaMachine.from_key_sheet( #set up an engima for testing
                        rotors=rotor_string,
                        reflector='B',
                        ring_settings=ring_settings,
                        plugboard_settings=current_plugboard)
                elif(resulting_char != expected_char):
                    return False, ""
                if neighbor not in visited:
                    queue.extend(neighbor)
    return True, current_plugboard


#TEST-CODE:

import string
test_cypher_text = 'ITXBSSLXTGTUYAHIYN'
plain_text = 'LOREMIPSUMDOLORSIT'
start_display = 'KYI'
graph = {letter: [] for letter in string.ascii_uppercase}
cypher_text_list = list(test_cypher_text)
plain_text_list = list(plain_text)
index_dict = {}
for i in range(0, len(test_cypher_text)):
    graph[cypher_text_list[i]].append(plain_text_list[i])
    graph[plain_text_list[i]].append(cypher_text_list[i])
    #index_list.append(cypher_text_list[i] + plain_text_list[i])
    identifier = find_identifier(cypher_text_list[i], plain_text_list[i])
    if(not identifier in index_dict):
        index_dict[identifier] = list([i])
    else:
        index_dict[identifier].append(i)
print("graph: " + str(graph))
reconstruct_plugboard(index_dict, graph, 'I II III', start_display, 'L', 'A A A', 'LS', find_enigma_display_positions_to_index('I II III', plain_text, start_display), plain_text, test_cypher_text)
# Out:
# graph: {'A': ['O'], 'B': ['E'], 'C': [], 'D': ['T'], 'E': ['B'], 'F': [], 'G': ['M'], 'H': ['R'], 'I': ['L', 'S', 'S', 'Y'], 'J': [], 'K': [], 'L': ['I', 'P', 'Y'], 'M': ['S', 'G'], 'N': ['T'], 'O': ['T', 'U', 'A'], 'P': ['L'], 'Q': [], 'R': ['X', 'H'], 'S': ['M', 'I', 'X', 'I'], 'T': ['O', 'U', 'D', 'N'], 'U': ['T', 'O'], 'V': [], 'W': [], 'X': ['R', 'S'], 'Y': ['L', 'I'], 'Z': []}
# (True, 'LS EI OP QY RM CX')

# %%
import string
import copy

import itertools
all_rotors = ['I', 'II', 'III', 'IV', 'V']


alphabet = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')


def get_plug(a: str, b: str, c:str, reconstruction:str):
            #this method reconstructs a plugboard connection from the letters seen during the loop iteration
            reconstruction = list(reconstruction)[-1]
            if(b==reconstruction):
                return a+c
            elif(c==reconstruction):
                return a+b
            else:
                return "[error: " + a + b + c + reconstruction + "]"

def run_turing_bombe(cycles: list, plain_text: str, cypher_text: str, graph:list, index_dict: dict, brute_force_right_ring_setting=False):
        print('SEARCHING FOR VALID ENIGMA CONFIGURATIONS')
        rotor_combinations = itertools.permutations(all_rotors, 3)
        number_trials = [0] * len(cycles)
        possible_configurations = list()
        for rotor_combination in rotor_combinations: #TODO: Richtigstellen
            rotor_selection = " ".join(rotor_combination) #TODO: Richtigstellen
            for last_ring in list(alphabet) if brute_force_right_ring_setting else ['A']:
                    brute_force_right_ring_setting=False
                    ring_settings = 'A A ' + last_ring
                    print('Running: Rotors: ' + rotor_selection + ' Ring Settings: ' + ring_settings)
                    display_iterator_enigma = EnigmaMachine.from_key_sheet(
                        rotors=rotor_selection,
                        reflector='B',
                        ring_settings=ring_settings,
                        plugboard_settings='')
                    display_iterator_enigma.set_display('AAA')
                    initial = True
                    while(initial or display_iterator_enigma.get_display() != 'AAA'):
                        enigma_display_array = find_enigma_display_positions_to_index(rotor_selection, plain_text, display_iterator_enigma.get_display())
                        valid_plugboard_for_display_exists = False
                        valid_plugboards_list = list()
                        for j in range(0, len(cycles)):
                            number_trials[j] += 1
                            valid_plugboards_list.append(list())

                            #List of the enigma configurations for every cycle edge
                            enigma_display_positions = [enigma_display_array[cycles[j]["index_list"][i]] for i in range(0, len(cycles[j]["index_list"]))]
                            
                            #determine the letter with which we start in the loop
                            start_letter = plain_text[cycles[j]["index_list"][0]] if plain_text[cycles[j]["index_list"][0]] == cycles[j]["cycle"][0] else cypher_text[cycles[j]["index_list"][0]]
                            for a in alphabet: 
                                plug_board = a + start_letter
                                if(plug_board==a + a):
                                    plug_board = ''
                                em = EnigmaMachine.from_key_sheet(
                                    rotors=rotor_selection,
                                    reflector='B',
                                    ring_settings=ring_settings,
                                    plugboard_settings=plug_board)
                                em.set_display(display_iterator_enigma.get_display())

                                l = list(start_letter)
                                for i in range(0, len(cycles[j]["index_list"])):
                                    em.set_display(enigma_display_positions[i])
                                    l.append(em.key_press(l[-1]))

                                if(l[0] == l[-1]):
                                    valid_plugboard, plugboard_reconstruction = reconstruct_plugboard(index_dict, graph, rotor_selection, display_iterator_enigma.get_display(), start_letter, ring_settings, plug_board, enigma_display_array, plain_text, cypher_text)
                                    if(valid_plugboard):
                                        valid_plugboards_list[-1].append(plugboard_reconstruction)
                                    #print(str(valid_plugboards_list) + " cycles: " + str(j) + "dispit " + display_iterator_enigma.get_display())

                            valid_plugboard_for_display_exists, valid_plugboards_list = check_plugboard_configurations(valid_plugboards_list)
                            if(not valid_plugboard_for_display_exists):
                                break
                                
                                
                        if valid_plugboard_for_display_exists:
                            for valid_pb in valid_plugboards_list[0]:
                                config = {'rotors' : rotor_selection,'ring-settings' : ring_settings, 'display' : display_iterator_enigma.get_display(), 'plugboard' : valid_pb}
                                config['hamming-distance'] = calc_hammingdistance_from_config(config, cypher_text, plain_text)
                                possible_configurations.append(config)
                                print(config)
                        display_iterator_enigma.key_press('A')
                        initial = False

        print("SEARCH FOR ENIGMA CONFIGURATIONS FINISHED")
        print("number of possible configurations: " + str(len(possible_configurations)))
        print('number of tried out configurations [per cycle]: ' + str(number_trials))
        print("------------------------------------------------------------------")
        return possible_configurations


def break_enigma(cypher_text: str, plain_text: str, brute_force_right_ring_setting=False):
    if(len(cypher_text) != len(plain_text)):
            print('Error: Different length of cypher_text and plain text!')
            return
    print("CRIB:       " + plain_text)
    print("CYPHERTEXT: " + cypher_text)
    print("TURNOVERPROBABILITY: " + str(round(min(len(cypher_text) / 26, 1) * 100, 2)) + '%')
    print("TURING-BOMBE IS RUNNING...")
    cypher_text = cypher_text[:min(35, len(cypher_text))] #limit length of cypher_text and plain text
    plain_text = plain_text[:min(35, len(plain_text))]
    graph = {letter: [] for letter in string.ascii_uppercase}
    cypher_text_list = list(cypher_text)
    plain_text_list = list(plain_text)
    index_dict = {}
    for i in range(0, len(cypher_text)):
        graph[cypher_text_list[i]].append(plain_text_list[i])
        graph[plain_text_list[i]].append(cypher_text_list[i])
        identifier = find_identifier(cypher_text_list[i], plain_text_list[i])
        if(not identifier in index_dict):
            index_dict[identifier] = list([i])
        else:
            index_dict[identifier].append(i)
    print("graph: " + str(graph))
    
    bare_cycles = find_all_cycles(graph, k=5)

    if(len(bare_cycles) < 1):
        print('Sorry, no loops in crib and cypher text found!')
        return

    print("cycles: " + str(bare_cycles))
    print("edge indices: " + str(index_dict))
    #store cycles in a dictionary
    cycles = [{"cycle": cycle} for cycle in bare_cycles]
    for i in range(0, len(cycles)):
        cycles[i]["index_list"] = list()
        index_dict_pop = copy.deepcopy(index_dict)
        for node in range(1, len(cycles[i]["cycle"])):
            #create a list, which contains for every edge in the cycle the corresponding index where the two letters are translated into each other
            cycles[i]["index_list"].append(index_dict_pop[find_identifier(cycles[i]["cycle"][node - 1], cycles[i]["cycle"][node])].pop(0))
        #add the last edge
        cycles[i]["index_list"].append(index_dict_pop[find_identifier(cycles[i]["cycle"][-1], cycles[i]["cycle"][0])].pop(0))

    #get find possible enigma configurations and sort them by the hamming distance between crib and cyphertext
    possible_configurations = sorted(run_turing_bombe(cycles, plain_text_list, cypher_text_list, graph, index_dict), key=lambda d: d['hamming-distance'])

    print("CHECKING ALL IDENTIFIED CONFIGURATIONS")
    for config in possible_configurations: #try out all configurations, starting with the lowest hamming-distance
        success = brute_force_remaining_plugboard(config, cypher_text, plain_text)
        if success:
            return

# %%
plain_text = "WEATHERISCLEAR"
m1 = EnigmaMachine.from_key_sheet(
       rotors='I II III',
       reflector='B',
       ring_settings="A A A",
       plugboard_settings='OP TF SL RM QY IE DJ ZN CX UW')

m1.set_display('AAA')
code1 = m1.process_text(plain_text)

break_enigma(cypher_text=code1, plain_text=plain_text)
# Out:
# CRIB:       WEATHERISCLEAR
# CYPHERTEXT: NPNFRSPQAMDCBM
# TURNOVERPROBABILITY: 53.85%
# TURING-BOMBE IS RUNNING...
# graph: {'A': ['N', 'S', 'B'], 'B': ['A'], 'C': ['M', 'E'], 'D': ['L'], 'E': ['P', 'S', 'C'], 'F': ['T'], 'G': [], 'H': ['R'], 'I': ['Q'], 'J': [], 'K': [], 'L': ['D'], 'M': ['C', 'R'], 'N': ['W', 'A'], 'O': [], 'P': ['E', 'R'], 'Q': ['I'], 'R': ['H', 'P', 'M'], 'S': ['E', 'A'], 'T': ['F'], 'U': [], 'V': [], 'W': ['N'], 'X': [], 'Y': [], 'Z': []}
# cycles: [['C', 'M', 'R', 'P', 'E']]
# edge indices: {'NW': [0], 'EP': [1], 'AN': [2], 'FT': [3], 'HR': [4], 'ES': [5], 'PR': [6], 'IQ': [7], 'AS': [8], 'CM': [9], 'DL': [10], 'CE': [11], 'AB': [12], 'MR': [13]}
# SEARCHING FOR VALID ENIGMA CONFIGURATIONS
# Running: Rotors: I II III Ring Settings: A A A
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'AAA', 'plugboard': 'XC RM IE OP LS ZN UW', 'hamming-distance': 2}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'BNY', 'plugboard': 'HK BY JE IR LP XS OA DN', 'hamming-distance': 6}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'BZF', 'plugboard': 'BJ AQ DE TR YP VS ZH ON LW', 'hamming-distance': 6}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'CFQ', 'plugboard': 'JC TM WX QP BD GH VA ZN', 'hamming-distance': 8}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'CZN', 'plugboard': 'WH QE BO VP ZA XN', 'hamming-distance': 7}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'DOF', 'plugboard': 'BC UM OE XR AP JS NT ZW', 'hamming-distance': 4}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'DTH', 'plugboard': 'HJ TM QE KR OP FA GN DB XW', 'hamming-distance': 5}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'FKS', 'plugboard': 'JC WX UE KR LP AS FH TB', 'hamming-distance': 5}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'FRQ', 'plugboard': 'OC LM TE NY KP US BV ZA FW', 'hamming-distance': 5}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'FTQ', 'plugboard': 'AI VE YR UP TS NJ OB KW', 'hamming-distance': 6}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'GYP', 'plugboard': 'ZC LM FE AN HX OB IW', 'hamming-distance': 6}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'JIW', 'plugboard': 'WC AK YR DP XS ON UB', 'hamming-distance': 5}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'JTK', 'plugboard': 'FC WX NV QR DP BO JH TA', 'hamming-distance': 9}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'KVF', 'plugboard': 'XC TM KE VP DS IH YA JN QB FW', 'hamming-distance': 2}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'KZA', 'plugboard': 'LC GE WR JP FS KH XA DN UB', 'hamming-distance': 3}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'LOJ', 'plugboard': 'DC FM GE WZ BU JS IH ON', 'hamming-distance': 7}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'MJD', 'plugboard': 'XC BE UR GP FS WV YA DN', 'hamming-distance': 9}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'MYA', 'plugboard': 'TC NY GE VR BO KS FH LA UW', 'hamming-distance': 7}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'MYF', 'plugboard': 'JC DM QE BX RZ AI TN VW', 'hamming-distance': 5}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'NEW', 'plugboard': 'UC QE YR LP XS VH OA ZN DB FW', 'hamming-distance': 3}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'QSQ', 'plugboard': 'WQ LE XR OP BT KH ZA UN', 'hamming-distance': 7}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'QUK', 'plugboard': 'KC TM ZE DR BP YS XH GN FW', 'hamming-distance': 3}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'RQT', 'plugboard': 'YC WT NI QR JP VS GH KA XB', 'hamming-distance': 7}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'RUZ', 'plugboard': 'XC FM QE TR JP BG LH YA VW', 'hamming-distance': 5}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'RAB', 'plugboard': 'HZ XM UE TP JS DA LB KW', 'hamming-distance': 5}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'SKV', 'plugboard': 'QC XM HE BI KP JS ZA UN DW', 'hamming-distance': 6}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'TIG', 'plugboard': 'BJ AZ IE WT VS GH ON', 'hamming-distance': 8}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'TKG', 'plugboard': 'VC ZM DE OP QS NA RB LW', 'hamming-distance': 6}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'UAF', 'plugboard': 'OC BG AT FR ZP LS XH QN KW', 'hamming-distance': 8}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'VLJ', 'plugboard': 'XC UE KR WJ ZH DA ON', 'hamming-distance': 5}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'VSB', 'plugboard': 'GC UM VE AL JS TH DN YB OW', 'hamming-distance': 5}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'VUQ', 'plugboard': 'FC JM VE AR KP QS UH DN ZB XW', 'hamming-distance': 3}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'XWL', 'plugboard': 'HK LM ZE IR YP WV OA GN JB', 'hamming-distance': 7}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'YWT', 'plugboard': 'IC YM QE XR TP FS OH LA KN VW', 'hamming-distance': 3}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'ZUX', 'plugboard': 'NC BU TE DR YA SW', 'hamming-distance': 7}
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'ALF', 'plugboard': 'FC AI KE WR ZP GH YN SB', 'hamming-distance': 6}
# Running: Rotors: I II IV Ring Settings: A A A
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'DUH', 'plugboard': 'HA NF VE IR GP ZS WQ LB', 'hamming-distance': 6}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'DYQ', 'plugboard': 'QC GM FE YP XS WU IA VB', 'hamming-distance': 4}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'DYY', 'plugboard': 'LC XM VE UR ZP FS GH OA YB', 'hamming-distance': 3}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'EWE', 'plugboard': 'AG NF WY DP KS ZH MB', 'hamming-distance': 9}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'FSH', 'plugboard': 'GC RM QE XP HW BI ON', 'hamming-distance': 5}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'FWK', 'plugboard': 'XE DR BO VS FH JA QN YW', 'hamming-distance': 5}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'GPB', 'plugboard': 'HA YM WX TS KN BQ', 'hamming-distance': 8}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'HCZ', 'plugboard': 'IC OM UE GS XH DA JN RB LW', 'hamming-distance': 6}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'IPT', 'plugboard': 'KM VP WG FH QA RN OB', 'hamming-distance': 8}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'IWK', 'plugboard': 'AI KM ZE XP DS WL YN OB', 'hamming-distance': 6}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'IAS', 'plugboard': 'WC DM JE VR QS LH XA YN KB', 'hamming-distance': 3}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'JMM', 'plugboard': 'GC JM ND TP BH KA YW', 'hamming-distance': 6}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'KGY', 'plugboard': 'ZC AD NV BL XS QH UW', 'hamming-distance': 9}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'KZS', 'plugboard': 'KC BD OE VP LH FA QN', 'hamming-distance': 5}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'LKJ', 'plugboard': 'JC YM QE UP DS AH TN FB IW', 'hamming-distance': 3}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'MTE', 'plugboard': 'LM GE IR KP OS NZ CA DB TW', 'hamming-distance': 6}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'MTG', 'plugboard': 'QC BT AP FR IS NX LW', 'hamming-distance': 10}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'NMY', 'plugboard': 'IC PM NU ZR TS VH DA OB KW', 'hamming-distance': 6}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'NDW', 'plugboard': 'AD LM UR QS OH VN TB YW', 'hamming-distance': 5}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'PFJ', 'plugboard': 'WQ XE LR FP HV NY ZA', 'hamming-distance': 6}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'QRR', 'plugboard': 'BT YM VE XR IP GS QH JA DN', 'hamming-distance': 5}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'RXF', 'plugboard': 'XC UM LR GP QS IH VA JN DB TW', 'hamming-distance': 3}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'RYJ', 'plugboard': 'DC BT NK OR JP WZ YA', 'hamming-distance': 9}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'SXK', 'plugboard': 'LM NI YR VP DH UA ZB SW', 'hamming-distance': 7}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'TZD', 'plugboard': 'NO QM DE HI WA VB', 'hamming-distance': 6}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'TDZ', 'plugboard': 'HB LM WG UR TS DA FN', 'hamming-distance': 6}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'VMD', 'plugboard': 'GM FR NO KS XH JA ZB EW', 'hamming-distance': 7}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'VMJ', 'plugboard': 'NY BJ KE VR AL GS QH OW', 'hamming-distance': 7}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'VZI', 'plugboard': 'WF JM AP VR YS ZH ON', 'hamming-distance': 8}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'ZFT', 'plugboard': 'KC UE YR TP DS VH FN ZB MW', 'hamming-distance': 5}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'ZVO', 'plugboard': 'UC TM BR OP QS WY EN', 'hamming-distance': 6}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'AOB', 'plugboard': 'BX NO QE FR AD US VH LW', 'hamming-distance': 8}
# {'rotors': 'I II IV', 'ring-settings': 'A A A', 'display': 'AYN', 'plugboard': 'VC SM NI UR TP DA ZB GW', 'hamming-distance': 4}
# Running: Rotors: I II V Ring Settings: A A A
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'AAE', 'plugboard': 'AT OM NK GR DP YH LB VW', 'hamming-distance': 7}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'CPI', 'plugboard': 'TC ZM BV FR GP KS IH UA OW', 'hamming-distance': 6}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'ETH', 'plugboard': 'BC WI DE FR JP VS NU ZA', 'hamming-distance': 5}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'FFC', 'plugboard': 'WM AV IR KP OS NQ TB', 'hamming-distance': 7}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'FIG', 'plugboard': 'BT AK QR LP VS WD XN', 'hamming-distance': 9}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'FYY', 'plugboard': 'OC BJ ZE PR XS UH VN FW', 'hamming-distance': 5}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'GYW', 'plugboard': 'FC OM QE AR YP ZS JH DN VW', 'hamming-distance': 3}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'HZK', 'plugboard': 'IC BK WQ JP VS UH TA DN', 'hamming-distance': 9}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'INK', 'plugboard': 'AY BU KE VR XP ZS QH DN IW', 'hamming-distance': 6}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'KFR', 'plugboard': 'AQ ZM UE BJ TP YS NK XW', 'hamming-distance': 8}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'KYY', 'plugboard': 'KC TM NF VR AG YS ZH QB DW', 'hamming-distance': 7}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'LME', 'plugboard': 'ZC YM NU VR FP JH GA SB OW', 'hamming-distance': 7}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'LWF', 'plugboard': 'VC IM OE DR XS ZH PA TN FB KW', 'hamming-distance': 5}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'NJH', 'plugboard': 'NY ZM DE KR AV FH BX LW', 'hamming-distance': 10}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'NSU', 'plugboard': 'YC RM UE DP LS NV TA FW', 'hamming-distance': 4}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'ORT', 'plugboard': 'IC XM QE PD OS UB KW', 'hamming-distance': 5}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'PQK', 'plugboard': 'GC ZM IE VP NQ OA UB DW', 'hamming-distance': 4}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'RTJ', 'plugboard': 'TC BJ WV XR IS KH FA PN', 'hamming-distance': 9}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'SXW', 'plugboard': 'AJ BQ VR TP KS DH UN OW', 'hamming-distance': 7}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'TMN', 'plugboard': 'YC NB FE GR VP IS QH LA UW', 'hamming-distance': 5}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'UNV', 'plugboard': 'AL TM NF JP ZS QH GW', 'hamming-distance': 7}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'UBP', 'plugboard': 'TC NB YE OR UP KS ZH IW LA', 'hamming-distance': 7}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'VRT', 'plugboard': 'AX OM KR WG TS VH ZN YB', 'hamming-distance': 7}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'VCJ', 'plugboard': 'YC GM QE NU VP BS ZH IA DW', 'hamming-distance': 6}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'XSO', 'plugboard': 'HC WG OE IR QP ZS JA FN TB', 'hamming-distance': 5}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'ZGK', 'plugboard': 'UC KM VE TR ZP JS QH DN OB YW', 'hamming-distance': 2}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'ZNL', 'plugboard': 'WY FM NX LR KP GS TH OA QB', 'hamming-distance': 7}
# {'rotors': 'I II V', 'ring-settings': 'A A A', 'display': 'AOW', 'plugboard': 'WD QM IE KR TP VH LA', 'hamming-distance': 5}
# Running: Rotors: I III II Ring Settings: A A A
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'BDL', 'plugboard': 'GC OM BI DR ZP KS QH VW', 'hamming-distance': 6}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'CYV', 'plugboard': 'SC YM FE QR TP BO DW', 'hamming-distance': 4}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'CNQ', 'plugboard': 'FM TE UR JP YS QH VA ZN DB IW', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'EER', 'plugboard': 'OC BQ VE DR LP YS AH FN KW', 'hamming-distance': 5}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'FZC', 'plugboard': 'QC UM OR LP XS VA GN JW', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'FSJ', 'plugboard': 'OM BU LR XP QH FA GN ZW', 'hamming-distance': 6}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'GGC', 'plugboard': 'GC VM IE QR SP JH YN TB DW', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'GJN', 'plugboard': 'OC TM WE IR XP DS BQ KA LN', 'hamming-distance': 4}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'GUU', 'plugboard': 'HW IE NS VP MB', 'hamming-distance': 11}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'IFO', 'plugboard': 'ZM VE NG JP FS TH UA IW', 'hamming-distance': 6}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'JHR', 'plugboard': 'FC QM NO JP HS GA EB IW', 'hamming-distance': 8}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'KKN', 'plugboard': 'LC OM FR NP QS TH VA YB UW', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'LID', 'plugboard': 'WC SM YE BG AT QH LN', 'hamming-distance': 7}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'MBK', 'plugboard': 'KC IM BU QR ZS NY XW', 'hamming-distance': 7}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'MGC', 'plugboard': 'GC QM BF JR KP US NH ZA IW', 'hamming-distance': 6}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'MUO', 'plugboard': 'YC AD GE WK HF IN TB', 'hamming-distance': 8}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'NMM', 'plugboard': 'XC LM IE BR AJ VS NY OW', 'hamming-distance': 6}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'OLS', 'plugboard': 'HK TM ZE LR DP XS ON QB VW', 'hamming-distance': 5}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'PJJ', 'plugboard': 'EM JR US YH DA PN GB CW', 'hamming-distance': 7}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'RWW', 'plugboard': 'VM KE WX JP IS CH GA ON UB', 'hamming-distance': 8}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'SGG', 'plugboard': 'IC NU JR OP WF BT VA', 'hamming-distance': 8}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'SIO', 'plugboard': 'XC HM UE FR GP TS KA ZN VB QW', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'SNK', 'plugboard': 'VC BL WR FP GS YH TA JN', 'hamming-distance': 6}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'SPX', 'plugboard': 'JC VM QE XS ZH LA KN PB OW', 'hamming-distance': 5}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'TFY', 'plugboard': 'PC OM VR AS GH DN YB ZW', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'VEN', 'plugboard': 'HY AV DE BX UP JS TN FW', 'hamming-distance': 8}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'VFX', 'plugboard': 'JM LE ZR IP VS QB DW', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'WXN', 'plugboard': 'NG XE JP ZS WO QA TB', 'hamming-distance': 6}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'WEG', 'plugboard': 'RC UM OE XP TH BA JN KW', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'WRO', 'plugboard': 'HK TM XE DR QS FA YN GB JW', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'WRV', 'plugboard': 'ZC WJ QE UR FP BV TH YA XN', 'hamming-distance': 7}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'WUR', 'plugboard': 'IC BE TR UP JS VH FA GN QW', 'hamming-distance': 8}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'XWI', 'plugboard': 'TC IM WS BR NL OH GA', 'hamming-distance': 7}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'XXR', 'plugboard': 'JC YM WT QR FS DH LN OB', 'hamming-distance': 6}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'XTR', 'plugboard': 'SC DM JE UR ZP GH YA KN IW', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'YLH', 'plugboard': 'LC ZM DE GP TS WX IA UN JB', 'hamming-distance': 3}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'ZYX', 'plugboard': 'NU VM XE QP GS KH DA ZB YW', 'hamming-distance': 5}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'ZDX', 'plugboard': 'HG QE DR BZ JS UA VN OW', 'hamming-distance': 7}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'ZGC', 'plugboard': 'KC NR FE QS YH UA DB GW', 'hamming-distance': 7}
# {'rotors': 'I III II', 'ring-settings': 'A A A', 'display': 'ZMI', 'plugboard': 'OC FM TE JR WU KA XN QB', 'hamming-distance': 5}
# Running: Rotors: I III IV Ring Settings: A A A
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'BYA', 'plugboard': 'UC NO XE BF AD QS GH VW', 'hamming-distance': 8}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'BKS', 'plugboard': 'EC YM IR XP ZS DH VA QN UB TW', 'hamming-distance': 3}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'CXI', 'plugboard': 'NJ VM WU BQ RT ZS AL', 'hamming-distance': 9}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'DXL', 'plugboard': 'LC ZM VE YR IP XS NU GB TW', 'hamming-distance': 4}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'EKE', 'plugboard': 'JC NZ YE DR FS TH KB OW', 'hamming-distance': 5}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'EKF', 'plugboard': 'DC BL WV FP NT YA', 'hamming-distance': 7}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'EMI', 'plugboard': 'NB XM YR TP JS QH FA OW', 'hamming-distance': 6}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'EPL', 'plugboard': 'ZC UM BX YR AQ NS FH JW', 'hamming-distance': 7}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'FZW', 'plugboard': 'YC AZ GE BL FP HQ KN', 'hamming-distance': 7}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'GTR', 'plugboard': 'NY TM IR WL KS GH FB', 'hamming-distance': 7}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'HCT', 'plugboard': 'VC FM YE ND IP OS BK UA ZW', 'hamming-distance': 6}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'IUE', 'plugboard': 'JC NM TE LR FP IS OH QA YB DW', 'hamming-distance': 3}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'JXF', 'plugboard': 'LC AQ TE HR OP DS YN JB', 'hamming-distance': 5}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'KXO', 'plugboard': 'TC IM NR WV ZH FA XB', 'hamming-distance': 9}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'KME', 'plugboard': 'MC SE NY IP JH XA VB TW', 'hamming-distance': 5}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'MBE', 'plugboard': 'FC LM VE JR SP BX GA DW', 'hamming-distance': 3}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'MNZ', 'plugboard': 'VC YM KE DR TS BF JA QN ZW', 'hamming-distance': 4}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'NHF', 'plugboard': 'QC AG OE TR IP US NK FB', 'hamming-distance': 6}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'NUF', 'plugboard': 'GC UM DE XP OS ZH JA FN RB QW', 'hamming-distance': 6}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'OQL', 'plugboard': 'BK TM WF XS JH GA', 'hamming-distance': 7}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'PAG', 'plugboard': 'HU BG QE ND YP TS OA LW', 'hamming-distance': 8}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'PPR', 'plugboard': 'YC WK TE NQ GP JS DH XA IB', 'hamming-distance': 7}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'QIM', 'plugboard': 'NJ UM BF EK VR OP HL DA IW', 'hamming-distance': 6}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'RYA', 'plugboard': 'IC YM BX QR NF US AH DW', 'hamming-distance': 7}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'TRH', 'plugboard': 'ZM QE TP IS BO WA', 'hamming-distance': 4}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'WKH', 'plugboard': 'FC AV ZE SR LH QN JB UW', 'hamming-distance': 5}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'ZMQ', 'plugboard': 'JM AU WZ XH FB', 'hamming-distance': 5}
# {'rotors': 'I III IV', 'ring-settings': 'A A A', 'display': 'ZRQ', 'plugboard': 'IC XM WT VR OP YS JH KN LB', 'hamming-distance': 5}
# Running: Rotors: I III V Ring Settings: A A A
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'AIY', 'plugboard': 'OC NQ BF AT ER GW', 'hamming-distance': 10}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'AQC', 'plugboard': 'IM VE NU XP BD TA GW', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'BEH', 'plugboard': 'AD XM HE QR UP FS YN JB KW', 'hamming-distance': 5}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'BKC', 'plugboard': 'KC UE YP ZS BA JN IW', 'hamming-distance': 3}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'BKV', 'plugboard': 'IC KM DE NU LP QS ZA YB HW', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'BRK', 'plugboard': 'JC OM FE NT AU XS VH ZB YW', 'hamming-distance': 7}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'BSI', 'plugboard': 'QC YM TE ZR LP KH GA UN DB FW', 'hamming-distance': 3}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'CWP', 'plugboard': 'LC AM NE OR UP TS IH DB ZW', 'hamming-distance': 3}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'CDB', 'plugboard': 'UM DE YR GP BC JA FN ZW', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'CSA', 'plugboard': 'KC WV NZ IP TH OA XB', 'hamming-distance': 8}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'DDU', 'plugboard': 'AQ GM YE ZR JP VS LH IN OB', 'hamming-distance': 5}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'EMV', 'plugboard': 'TC YM WD NZ XP VS GH OB', 'hamming-distance': 9}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'FJD', 'plugboard': 'BV KM TR UP HW FE DA XN', 'hamming-distance': 7}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'GFY', 'plugboard': 'TC RM NE IP WS ZA LB', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'HYV', 'plugboard': 'BU LE KR FP VS DH JA ON QW', 'hamming-distance': 5}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'IIK', 'plugboard': 'AG NQ JR VP KS DH TB EW', 'hamming-distance': 8}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'IOE', 'plugboard': 'IM YE LR XP ZS DH UA QN OB', 'hamming-distance': 3}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'JOU', 'plugboard': 'DC LM BO WV TP US FH ZA KN', 'hamming-distance': 8}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'KTJ', 'plugboard': 'VC JM KR GP AW LN EB', 'hamming-distance': 8}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'LDD', 'plugboard': 'DC JE QR WZ US NY GA OB', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'LLC', 'plugboard': 'WH QM VE YR UP ZS LN IB', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'LNU', 'plugboard': 'FC VE XR UP DH YA TN ZW', 'hamming-distance': 3}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'MEG', 'plugboard': 'JC RM IP ZS KH XA FN LB DW', 'hamming-distance': 3}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'OYR', 'plugboard': 'KC RE OP DS GH ZA VN IW', 'hamming-distance': 3}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'OHZ', 'plugboard': 'FC NO YP XS IH WA MB', 'hamming-distance': 7}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'OKS', 'plugboard': 'IC NR WO ZH MA PB', 'hamming-distance': 9}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'ORB', 'plugboard': 'JC YM OE NX BS FH WA', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'PDN', 'plugboard': 'QC EI AO BV RX DP JS WH', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'PRZ', 'plugboard': 'GC QM UE XR FP OS YA DN KB TW', 'hamming-distance': 3}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'RGR', 'plugboard': 'AU YM FE VR WT HN IB', 'hamming-distance': 8}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'RTU', 'plugboard': 'TC XM DR YP JS BH ZA IN UW', 'hamming-distance': 2}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'TFO', 'plugboard': 'DC JM LE FR WY BZ KA VN', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'THN', 'plugboard': 'OC ZM XE JR TP GH LA DN VB UW', 'hamming-distance': 3}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'TQE', 'plugboard': 'JC NG UE TR OP DH FA KB QW', 'hamming-distance': 5}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'UCF', 'plugboard': 'OC IM LE VR XS ZH GA KN DW', 'hamming-distance': 2}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'VBJ', 'plugboard': 'QC FM BU DP OS LH GA VN TW', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'VIX', 'plugboard': 'FC VM NE KR GS WZ IA UB', 'hamming-distance': 4}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'VRT', 'plugboard': 'DC SM KE XR AF WI GN TB', 'hamming-distance': 4}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'XID', 'plugboard': 'BX YM JE NF DP OS KA ZW', 'hamming-distance': 8}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'XNY', 'plugboard': 'QC TM ZE UR GS IH YA VN XB PW', 'hamming-distance': 5}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'XQQ', 'plugboard': 'BV KE FR DP NS UA JW', 'hamming-distance': 5}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'YXH', 'plugboard': 'JC DM LE TP KS BI YA RW', 'hamming-distance': 6}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'YMH', 'plugboard': 'HM DE GR AY IS JN CB QW', 'hamming-distance': 7}
# {'rotors': 'I III V', 'ring-settings': 'A A A', 'display': 'ZUJ', 'plugboard': 'NX FM JR WV DS GH ZA', 'hamming-distance': 7}
# Running: Rotors: I IV II Ring Settings: A A A
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'AEH', 'plugboard': 'BJ GE YR XP FS NQ LA KW', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'BGF', 'plugboard': 'UC AL VE KR TP ZS QH OB XW', 'hamming-distance': 5}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'CCZ', 'plugboard': 'IC KM ZE NR OS UH GA VB FW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'CGZ', 'plugboard': 'OC JE DR QP ZS NL FB UW', 'hamming-distance': 4}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'DYW', 'plugboard': 'NU AQ YR KP WL VH BI', 'hamming-distance': 10}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'DAE', 'plugboard': 'YC NL ZE XR AO FS QH KB GW', 'hamming-distance': 7}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'EQW', 'plugboard': 'FC XM VE UR KP IS QH OB JW', 'hamming-distance': 2}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'ESW', 'plugboard': 'BY UR HP QS IA LN MW', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'EAJ', 'plugboard': 'UM FE BL ZP QH VA GN JW', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'FLE', 'plugboard': 'OC BF SR IP NJ DW', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'FII', 'plugboard': 'NK BO IE UR SP WD JA', 'hamming-distance': 7}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'GOA', 'plugboard': 'HB JM YE OR AX IN', 'hamming-distance': 9}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'HBL', 'plugboard': 'XC RM VE DP IS KA TN JB YW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'IYC', 'plugboard': 'UC BW GR AQ YH DN', 'hamming-distance': 8}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'IEC', 'plugboard': 'LC DM UE GR ZP FS KH IA QN YW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'JEY', 'plugboard': 'YC GM IE XR US TH OA LN ZB QW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'KLN', 'plugboard': 'KC YE QR ZP GS LH UN XB JW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'LMD', 'plugboard': 'QM WL YR IH JA OB', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'MWJ', 'plugboard': 'FC WM BL ZP QS TH XA DN', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'MZT', 'plugboard': 'HV NM IR OP LS GA TB XW', 'hamming-distance': 8}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'NLI', 'plugboard': 'FC AO WI JP US LH VN DB', 'hamming-distance': 8}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'NNC', 'plugboard': 'TC ZM KE AL GN RB SW', 'hamming-distance': 9}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'OST', 'plugboard': 'LC BW HE YR OP FS VA QN', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'OET', 'plugboard': 'AQ YE BK JP FS VH DN IW', 'hamming-distance': 7}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'OIB', 'plugboard': 'LC BG AT IR NW ZS FH', 'hamming-distance': 8}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'PNF', 'plugboard': 'GC WR BF YP ZS VH JA DN', 'hamming-distance': 10}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'PNG', 'plugboard': 'FC RM JE DP KS LH OA GN IB TW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'PSI', 'plugboard': 'AX QM VE WR GP BI NY', 'hamming-distance': 8}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'PWB', 'plugboard': 'LC YM QE AG XS JH UN WB', 'hamming-distance': 5}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'QBR', 'plugboard': 'OC VM BL DR AF XS KH GN', 'hamming-distance': 7}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'QIG', 'plugboard': 'WY IM RE LP VA TN OB', 'hamming-distance': 5}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'RHJ', 'plugboard': 'DC FM OE TR VP US XH IA LB ZW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'STW', 'plugboard': 'NU FM ZE OR JP WS XH DA IB', 'hamming-distance': 5}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'SZL', 'plugboard': 'UE YR ZP NS FH TA JB IW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'SDL', 'plugboard': 'AT XE BU JP OS MN LW', 'hamming-distance': 8}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'TMY', 'plugboard': 'QM LE TR ZP KS WF DA YN OB', 'hamming-distance': 4}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'TTP', 'plugboard': 'EC KM XP LH UA ON TW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'TWF', 'plugboard': 'UC GM OE ZR BP LS QH IA VN TW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'UME', 'plugboard': 'NG OM KE ZR UP VS WJ YA QB', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'UZR', 'plugboard': 'AX LM WV YP FS GN UB', 'hamming-distance': 8}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'WFR', 'plugboard': 'YC AM XE BL ZP IH GN OW', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'XLU', 'plugboard': 'NM TE JR GP US BK DA VW', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'XBL', 'plugboard': 'JC AX OE KR ZP US NQ TB DW', 'hamming-distance': 6}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'XCP', 'plugboard': 'FC XM JE TR YP NS AD VB ZW', 'hamming-distance': 4}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'YRK', 'plugboard': 'VC EM BK TP DH IA QN SW', 'hamming-distance': 8}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'ZHH', 'plugboard': 'KC XM UE BR DS IH GA YN ZW', 'hamming-distance': 3}
# {'rotors': 'I IV II', 'ring-settings': 'A A A', 'display': 'AXZ', 'plugboard': 'VC NT ZE UR BF JS GH OA XW', 'hamming-distance': 7}
# Running: Rotors: I IV III Ring Settings: A A A
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'ACY', 'plugboard': 'LC WT GR XS NM FA JB', 'hamming-distance': 9}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'ACN', 'plugboard': 'JC AU ZE BQ XP KS LH FN TW', 'hamming-distance': 7}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'BSE', 'plugboard': 'VM NO BU ZP CH TA IW', 'hamming-distance': 10}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'DRE', 'plugboard': 'OC FM TE JR XS QH UA VN LB', 'hamming-distance': 3}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'EUO', 'plugboard': 'YM ZE OR JP HS LA QN DB TW', 'hamming-distance': 3}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'GOJ', 'plugboard': 'XC JE WK RT DP YS AZ FN LB', 'hamming-distance': 5}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'GBJ', 'plugboard': 'WG BZ OE TR YP FS KA VN', 'hamming-distance': 6}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'HBE', 'plugboard': 'JC TM WY OR AX LS UH FN DB', 'hamming-distance': 7}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'JMJ', 'plugboard': 'GC QM YE NF LS BZ OA VW', 'hamming-distance': 5}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'JAA', 'plugboard': 'IC KM LE OR US GH YA JN PB ZW', 'hamming-distance': 5}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'KOU', 'plugboard': 'NL UE KR QP IS XH JB FW', 'hamming-distance': 5}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'LYY', 'plugboard': 'JC VM BY IR OP GS AH UN QW', 'hamming-distance': 6}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'MTL', 'plugboard': 'RC BO LE KP VS NJ ZA YW', 'hamming-distance': 6}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'MWU', 'plugboard': 'BL AD OE NV QP GS YH JW', 'hamming-distance': 8}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'NNO', 'plugboard': 'ZC QE IR TP YS UH OA JN FB', 'hamming-distance': 3}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'NYT', 'plugboard': 'AT EM DR GP YS OH JN FB', 'hamming-distance': 5}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'OUH', 'plugboard': 'JC OM WK TR DP GS IA XN YB', 'hamming-distance': 6}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'QCN', 'plugboard': 'NY FM TR VP BO IH KA DW', 'hamming-distance': 7}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'RKI', 'plugboard': 'NL JM WF IR XP OS GH VA', 'hamming-distance': 7}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'RPS', 'plugboard': 'BC QM NF JR TP WK DH OA', 'hamming-distance': 7}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'RSQ', 'plugboard': 'NU GM FE YR WD XS BV ZA', 'hamming-distance': 8}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'SXI', 'plugboard': 'JC EM GR DS YH WN QB', 'hamming-distance': 3}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'VLS', 'plugboard': 'XC QM JE PR LS YH UA KB OW', 'hamming-distance': 2}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'VGS', 'plugboard': 'BJ QM ZE XR LP FS NK GA DW', 'hamming-distance': 6}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'WMJ', 'plugboard': 'JM OE PG RY DS AH CW', 'hamming-distance': 7}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'YIX', 'plugboard': 'NG DM ZE AR XP JS VH TB UW', 'hamming-distance': 4}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'ZRB', 'plugboard': 'DC AZ FE NO BL IS TH', 'hamming-distance': 7}
# {'rotors': 'I IV III', 'ring-settings': 'A A A', 'display': 'ZYB', 'plugboard': 'JC ZM AX YR TP IS GH UN LB', 'hamming-distance': 6}
# Running: Rotors: I IV V Ring Settings: A A A
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'AFA', 'plugboard': 'IM BK FH VN GW', 'hamming-distance': 5}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'BVA', 'plugboard': 'YC UM JE GR TP VS FH DA LN XW', 'hamming-distance': 3}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'CNZ', 'plugboard': 'DM UE ZR BP JS TH GA VN LW', 'hamming-distance': 3}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'CUE', 'plugboard': 'JC FM WU VP XS QA ON EB', 'hamming-distance': 9}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'EAO', 'plugboard': 'ND JM FE WZ AX KS UH', 'hamming-distance': 9}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'FTU', 'plugboard': 'UC BD FE VR AX IS LH YN GW', 'hamming-distance': 7}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'FZM', 'plugboard': 'IC FM AE BT ZP QS JH ON UW', 'hamming-distance': 6}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'FDA', 'plugboard': 'VC TM LE OR XS DH IA BN', 'hamming-distance': 3}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'FDK', 'plugboard': 'JC AI ZE OR BP FS GH TW', 'hamming-distance': 4}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'GWG', 'plugboard': 'LM WQ NR UP DS FH KA ZB', 'hamming-distance': 6}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'HWO', 'plugboard': 'VC WL ZE JP OS KH XA QN DB', 'hamming-distance': 5}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'HHA', 'plugboard': 'IC BZ WQ NO DP UH TA', 'hamming-distance': 10}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'ICA', 'plugboard': 'NU GE WR ZP TS LH VA QB', 'hamming-distance': 5}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'JQS', 'plugboard': 'IC AU LE NV QP WG DB', 'hamming-distance': 9}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'JZR', 'plugboard': 'YC HM IE KR JP US ON WB', 'hamming-distance': 3}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'KAC', 'plugboard': 'UC GE KR OP IS ZH YA DN VB', 'hamming-distance': 3}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'KHJ', 'plugboard': 'NY VE IR WB LS KH XA', 'hamming-distance': 7}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'LLD', 'plugboard': 'IC JM DR QP OS WU FA XN YB', 'hamming-distance': 4}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'LCO', 'plugboard': 'NU VM LR FP JS TH YA QB XW', 'hamming-distance': 5}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'MKJ', 'plugboard': 'BD GE TR YS NZ PA CW', 'hamming-distance': 9}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'MHG', 'plugboard': 'VC UM TE IR BO KN DW', 'hamming-distance': 5}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'MIC', 'plugboard': 'OC NM GE IR FP TS WH QB', 'hamming-distance': 3}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'NZJ', 'plugboard': 'DC WT UE FR LP YS NI VA ZB', 'hamming-distance': 5}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'NAN', 'plugboard': 'GC VE XR IP TS NZ UA YB LW', 'hamming-distance': 4}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'POV', 'plugboard': 'GC IM FE LR UP ZS WH KA DN VB', 'hamming-distance': 2}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'PYI', 'plugboard': 'AO NE IR VP WC ZH LB', 'hamming-distance': 8}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'QYY', 'plugboard': 'HV WJ DE XR UP IS TN OB', 'hamming-distance': 6}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'RNE', 'plugboard': 'QC BK ZE XR AT VH DN SW', 'hamming-distance': 9}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'RFK', 'plugboard': 'VC NZ OE YR DS KH GA IB JW', 'hamming-distance': 5}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'TRF', 'plugboard': 'IC NL TE XR BW KS FH OA', 'hamming-distance': 7}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'VKX', 'plugboard': 'QC TM IE VR LP ZS KH XA DB JW', 'hamming-distance': 3}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'VGV', 'plugboard': 'QC WO FE ZR DP JH GA XN', 'hamming-distance': 5}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'WMQ', 'plugboard': 'JC GM PE HX BF QA TN ZW', 'hamming-distance': 4}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'WRA', 'plugboard': 'UC LE QR BH VS IA ZN MW', 'hamming-distance': 8}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'WES', 'plugboard': 'QC IM UE BG XP VS NJ YA KW', 'hamming-distance': 6}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'XSR', 'plugboard': 'NV IM QE FR AJ KH LB XW', 'hamming-distance': 7}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'YTO', 'plugboard': 'RC GE DP XS OH VA KN YB TW', 'hamming-distance': 2}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'YBZ', 'plugboard': 'LM SE KR GP DH YA ON TB', 'hamming-distance': 3}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'ZLB', 'plugboard': 'WV IM AL EG ZR NP HK XB', 'hamming-distance': 6}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'ZFC', 'plugboard': 'TC NG FE AX US WQ ZB', 'hamming-distance': 8}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'AZD', 'plugboard': 'NL VM KE TR AY UH IB', 'hamming-distance': 7}
# {'rotors': 'I IV V', 'ring-settings': 'A A A', 'display': 'AZS', 'plugboard': 'LC BK UR WJ IS FH XN', 'hamming-distance': 7}
# Running: Rotors: I V II Ring Settings: A A A
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'ABA', 'plugboard': 'OC LM UR XP QS YH GA EN KB FW', 'hamming-distance': 6}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'BJQ', 'plugboard': 'IM DE JR NT VS AX BO FW', 'hamming-distance': 5}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'BJA', 'plugboard': 'ZC WG AX QR VP TS UH ON IB', 'hamming-distance': 8}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'CAY', 'plugboard': 'JC UM YE OR LP WQ KH VN IB', 'hamming-distance': 5}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'CNS', 'plugboard': 'HO QE PR VS FA YN KW', 'hamming-distance': 4}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'HKP', 'plugboard': 'IC AG WZ QR UP XS LH FN JB', 'hamming-distance': 8}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'IHS', 'plugboard': 'HU WY BI ZR OP JS DA GN', 'hamming-distance': 8}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'IMZ', 'plugboard': 'HL JM AX IR UP BZ TN KW', 'hamming-distance': 8}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'JKD', 'plugboard': 'XC LM PE BZ KS FA TN GW', 'hamming-distance': 6}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'KTL', 'plugboard': 'RC BZ NQ IP VH TA LW', 'hamming-distance': 8}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'LAW', 'plugboard': 'UC OM DE BW VP GS XH QA LN', 'hamming-distance': 6}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'LHS', 'plugboard': 'BG TE PD HI VM NJ AZ QW', 'hamming-distance': 7}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'MSZ', 'plugboard': 'XC ND ZE BP US QA FW', 'hamming-distance': 8}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'MVP', 'plugboard': 'XC SM YE WZ FP LA ON QB', 'hamming-distance': 6}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'NBA', 'plugboard': 'NP UM TE BK GS YH IA', 'hamming-distance': 9}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'NGB', 'plugboard': 'VC OM YE XR NT GA WQ', 'hamming-distance': 6}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'OJB', 'plugboard': 'XC IM VE TR BD AS KH QW', 'hamming-distance': 5}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'QPC', 'plugboard': 'HX TM OE BD IP VS KA GN JW', 'hamming-distance': 8}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'QTL', 'plugboard': 'DC JE BR ZP KS WM YA GN', 'hamming-distance': 6}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'RIV', 'plugboard': 'IC TM ZE DR UP BS KH OA GN QW', 'hamming-distance': 2}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'RNX', 'plugboard': 'NI DM QE TP WJ OH ZA LB', 'hamming-distance': 7}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'RUH', 'plugboard': 'NM GE BL UP TS QH IA KW', 'hamming-distance': 8}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'SVO', 'plugboard': 'LC XM BU KP YS FH GA VN IW', 'hamming-distance': 5}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'TIW', 'plugboard': 'DC LM XS YH JA QN EW', 'hamming-distance': 6}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'UNC', 'plugboard': 'AC KM BU LR YP WQ VH GN', 'hamming-distance': 7}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'WIB', 'plugboard': 'BE QM JR FP DS YH VN UW', 'hamming-distance': 7}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'WLG', 'plugboard': 'WL AM UE KR JP YS OH', 'hamming-distance': 5}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'XDN', 'plugboard': 'ZC FM WQ BI NK TS JH DA', 'hamming-distance': 9}
# {'rotors': 'I V II', 'ring-settings': 'A A A', 'display': 'YHJ', 'plugboard': 'IM LE UP KS WV TA CN YB', 'hamming-distance': 6}
# Running: Rotors: I V III Ring Settings: A A A
# {'rotors': 'I V III', 'ring-settings': 'A A A', 'display': 'ACI', 'plugboard': 'BG FM KE ZR NI YS XH QA UW', 'hamming-distance': 7}
# {'rotors': 'I V III', 'ring-settings': 'A A A', 'display': 'AMR', 'plugboard': 'WC IM OE YR XP JS BL FA ZN', 'hamming-distance': 4}
# {'rotors': 'I V III', 'ring-settings': 'A A A', 'display': 'BNX', 'plugboard': 'JC GE FP ZS MA BH LW', 'hamming-distance': 7}
# {'rotors': 'I V III', 'ring-settings': 'A A A', 'display': 'CJC', 'plugboard': 'QC AZ BO WR VP FS XH KN', 'hamming-distance': 8}
# {'rotors': 'I V III', 'ring-settings': 'A A A', 'display': 'DIS', 'plugboard': 'ZC FM DE BO JP IS KW', 'hamming-distance': 6}
# {'rotors': 'I V III', 'ring-settings': 'A A A', 'display': 'EHM', 'plugboard': 'ZC JM WE XR KP TS IH FA UN QB', 'hamming-distance': 3}
# ...
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'LYW', 'plugboard': 'HJ WV KE TR GP FS QA UB', 'hamming-distance': 6}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'MDB', 'plugboard': 'SM FE IR XP JH VA ON CB UW', 'hamming-distance': 5}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'OLE', 'plugboard': 'NL TR JP US FH OA DB VW', 'hamming-distance': 5}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'QMY', 'plugboard': 'SM ZE LR WT VH JA CN DB', 'hamming-distance': 7}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'QPN', 'plugboard': 'HF ZM YE NT VP US JB IW', 'hamming-distance': 7}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'RCH', 'plugboard': 'XC DM NY EV TP HO UA QB GW', 'hamming-distance': 5}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'RGE', 'plugboard': 'XC DM QP KS TH LA FN ZB IW', 'hamming-distance': 3}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'TCX', 'plugboard': 'IC LM DE UR GP JS KH ZA FN WB', 'hamming-distance': 2}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'VIX', 'plugboard': 'ZC LM IE GR BP XS KH QA TN DW', 'hamming-distance': 3}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'VTX', 'plugboard': 'UC BW ZE QR NV HO LA', 'hamming-distance': 8}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'XWO', 'plugboard': 'HX GM YE UR NV DS ZA LB JW', 'hamming-distance': 7}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'XDV', 'plugboard': 'NJ QM UE AX WR SB', 'hamming-distance': 11}
# {'rotors': 'V III IV', 'ring-settings': 'A A A', 'display': 'XTT', 'plugboard': 'JC XM KP GS QH UA IN VB LW', 'hamming-distance': 2}
# Running: Rotors: V IV I Ring Settings: A A A
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'BDY', 'plugboard': 'GC ZM WL YR FS XH OA BN', 'hamming-distance': 6}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'BFJ', 'plugboard': 'GC WI QE ZR UP NS TH DA KB', 'hamming-distance': 5}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'CLS', 'plugboard': 'WU KM DE IR YP QS XH TA FN', 'hamming-distance': 5}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'DWR', 'plugboard': 'HT KE FR AD MN QB GW', 'hamming-distance': 8}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'ELZ', 'plugboard': 'NQ IE OR YP US ZH BA WM', 'hamming-distance': 7}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'EGY', 'plugboard': 'FC LM DE VR AJ XH UB SW', 'hamming-distance': 7}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'GKV', 'plugboard': 'JM KE ZR YP LS CH OA DB FW', 'hamming-distance': 5}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'GKB', 'plugboard': 'HL KM QE TR ZP WF YA BN', 'hamming-distance': 7}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'HZI', 'plugboard': 'QC BL UE OR FP YS ZH DA TW', 'hamming-distance': 5}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'HCQ', 'plugboard': 'DC WI LE GR NT YS BV JA', 'hamming-distance': 8}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'IKB', 'plugboard': 'JC KM GE OR DP TS XA FN WY', 'hamming-distance': 3}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'IPJ', 'plugboard': 'DC AL NG WK UP VS JH QB', 'hamming-distance': 9}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'ITT', 'plugboard': 'HX GM TR QP FA VN JB OW', 'hamming-distance': 5}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'ITK', 'plugboard': 'HN OM DE LR GP VS ZA XB IW', 'hamming-distance': 5}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'JYU', 'plugboard': 'OC QM LR IP WY JH DN TB', 'hamming-distance': 5}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'LWP', 'plugboard': 'OC ZM FR TP KS VH YA WN GB', 'hamming-distance': 3}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'LYJ', 'plugboard': 'HG YM JE XP OS TA UB IW', 'hamming-distance': 5}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'LDU', 'plugboard': 'FC OM DE AR XP VS NI GW', 'hamming-distance': 3}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'MWB', 'plugboard': 'LM NY WX OP US QH JA', 'hamming-distance': 9}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'NCZ', 'plugboard': 'XC KM HE WQ OP FS TA LN GB', 'hamming-distance': 6}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'OSF', 'plugboard': 'XM IE AG VS BZ FN', 'hamming-distance': 6}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'OCR', 'plugboard': 'GC ZM AF NO KS IH WL UB', 'hamming-distance': 11}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'QEG', 'plugboard': 'LC UM SR BZ KH VA YN JW', 'hamming-distance': 5}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'RSU', 'plugboard': 'IC AT NL BO GP DS JH VW', 'hamming-distance': 10}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'SPN', 'plugboard': 'LC TM BY JR ZP FS XH QN OW', 'hamming-distance': 6}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'SZA', 'plugboard': 'HL NR AK XP DS IB YW', 'hamming-distance': 10}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'TOS', 'plugboard': 'OC KM XE YR QP GS AT VN IW', 'hamming-distance': 4}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'UTP', 'plugboard': 'UC FM ZR GP QS OH VA XN DB TW', 'hamming-distance': 3}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'VRV', 'plugboard': 'NM XE IR UP FS ZH GA TW', 'hamming-distance': 5}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'WSA', 'plugboard': 'BW KE QR VP TS IH LA GN', 'hamming-distance': 6}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'WGG', 'plugboard': 'JC OM NF XP WS LH UA DB', 'hamming-distance': 6}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'YRQ', 'plugboard': 'VC YM DE BZ TP XS QA IN LW', 'hamming-distance': 6}
# {'rotors': 'V IV I', 'ring-settings': 'A A A', 'display': 'ZWT', 'plugboard': 'YM GE AR XP ZS VH CN LB', 'hamming-distance': 5}
# Running: Rotors: V IV II Ring Settings: A A A
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'BZF', 'plugboard': 'AF RM KE GP IS LH DN BW', 'hamming-distance': 7}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'CDY', 'plugboard': 'UC PM IR XH WA JN QB', 'hamming-distance': 2}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'CGW', 'plugboard': 'JC BU XE LP HT YN ZW', 'hamming-distance': 6}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'DMZ', 'plugboard': 'LC AU WD JR FP OS QH YN IB', 'hamming-distance': 8}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'DQH', 'plugboard': 'GC IM UE JR OS FH VA DN ZB', 'hamming-distance': 3}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'DTZ', 'plugboard': 'GC OM DE BJ NI WU LH KA', 'hamming-distance': 9}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'DYP', 'plugboard': 'DC EM UR BF ZS QH LA JN YW', 'hamming-distance': 5}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'DBZ', 'plugboard': 'QC NF DP TS GH XA ZB JW', 'hamming-distance': 5}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'FOE', 'plugboard': 'UC XE OR BJ YS VH LA MW', 'hamming-distance': 6}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'FRE', 'plugboard': 'FC UM NJ QR DP YS KA WV', 'hamming-distance': 7}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'GWN', 'plugboard': 'XC AM VR QP NL UB GW', 'hamming-distance': 8}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'HTL', 'plugboard': 'UC JM AL GR WF VS BQ TN', 'hamming-distance': 10}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'HGR', 'plugboard': 'IM OE WD ZP QS NV LA JB', 'hamming-distance': 6}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'IZA', 'plugboard': 'UC QM FE NL BW JS YH XA', 'hamming-distance': 8}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'IBQ', 'plugboard': 'KC AG LE ZR YS TH UN JB VW', 'hamming-distance': 4}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'KZK', 'plugboard': 'QC IM ZE AR NU FS VH YB JW', 'hamming-distance': 5}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'LYY', 'plugboard': 'IC UM XE TR JP HV QA YN LB', 'hamming-distance': 4}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'LIL', 'plugboard': 'VC LM WQ ZP US XH GA JN KB', 'hamming-distance': 6}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'MHH', 'plugboard': 'GC PM XE TR HZ JA DN QB LW', 'hamming-distance': 4}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'NGY', 'plugboard': 'WJ XE KR YP VS NZ OA IB', 'hamming-distance': 6}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'NIB', 'plugboard': 'WL BY TP DS QH UA ON', 'hamming-distance': 8}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'OYT', 'plugboard': 'NJ LM ZR KP DS TH XA WU YB', 'hamming-distance': 7}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'QFW', 'plugboard': 'HV LE WM BF TS IA JN', 'hamming-distance': 9}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'RQS', 'plugboard': 'QC UM JR LP WZ NF TA OB', 'hamming-distance': 5}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'RVU', 'plugboard': 'QC GM BJ YR TP OS VH DA ZW', 'hamming-distance': 6}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'RXI', 'plugboard': 'UC KM XE IR ZS TH GN OB PW', 'hamming-distance': 5}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'TPE', 'plugboard': 'GC YM WI NK BS DH ZA', 'hamming-distance': 10}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'UOX', 'plugboard': 'UC VE QR BL IS TH ZA KN OW', 'hamming-distance': 5}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'URQ', 'plugboard': 'JC SM BL YR QH IN OW', 'hamming-distance': 6}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'UDA', 'plugboard': 'YC JE FR WO BG KH XA IN', 'hamming-distance': 7}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'VOR', 'plugboard': 'FC WV KE YR ZS LH GA DN OB', 'hamming-distance': 5}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'WUC', 'plugboard': 'DC AZ BE WK OP VS IH YN', 'hamming-distance': 7}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'YZB', 'plugboard': 'NU FM ZE TR OP KS GH JA WX', 'hamming-distance': 7}
# {'rotors': 'V IV II', 'ring-settings': 'A A A', 'display': 'AOC', 'plugboard': 'QC VM OE FR LP ZS DH YA XN KB', 'hamming-distance': 3}
# Running: Rotors: V IV III Ring Settings: A A A
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'AFG', 'plugboard': 'KM GE OR BD TS NY ZA UW', 'hamming-distance': 6}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'BWD', 'plugboard': 'FC IM QE XR BL NS AD UW', 'hamming-distance': 6}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'CKA', 'plugboard': 'HC BI NJ OP DS FA GW', 'hamming-distance': 7}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'CUY', 'plugboard': 'TC QM AV YR ZP LS NU IB OW', 'hamming-distance': 7}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'DEJ', 'plugboard': 'ZC YM DE NV OP BG QH TW', 'hamming-distance': 8}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'DET', 'plugboard': 'HD FM YR AV ZS JN GB QW', 'hamming-distance': 7}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'DGG', 'plugboard': 'EC ZM VR FP DH IA KN TB OW', 'hamming-distance': 3}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'EOR', 'plugboard': 'JC WM TE XR VP IH KA LN ZB', 'hamming-distance': 3}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'EBG', 'plugboard': 'JC RM XE YP OS IH GA DN LB ZW', 'hamming-distance': 3}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'EDN', 'plugboard': 'SC XM AQ NF IP UH ZB GW', 'hamming-distance': 8}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'FVJ', 'plugboard': 'BP QM YE OR WU LH GA XN', 'hamming-distance': 9}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'HGM', 'plugboard': 'DM BC FP ZS QH OA LN KW', 'hamming-distance': 8}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'IXD', 'plugboard': 'NO ZM JE WK YS GH IA DB', 'hamming-distance': 8}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'IBC', 'plugboard': 'AK XM NI TR OP WZ VB', 'hamming-distance': 8}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'KNU', 'plugboard': 'FC YM XE OR GP DS LA HN ZB IW', 'hamming-distance': 4}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'KHX', 'plugboard': 'ZC UE NL DP TS QH JA MB KW', 'hamming-distance': 7}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'LSP', 'plugboard': 'GC ZE OR LP XS BT QA KN MW', 'hamming-distance': 6}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'LXL', 'plugboard': 'LC OM ZE YP WS GH IA VN TB', 'hamming-distance': 3}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'LXM', 'plugboard': 'NV DE YR FP OS BC LA IW', 'hamming-distance': 7}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'MUL', 'plugboard': 'SC GM WE PT AK ZN YB', 'hamming-distance': 5}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'MDF', 'plugboard': 'RC OE BJ XS LH ZA VN UW', 'hamming-distance': 5}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'MER', 'plugboard': 'NK TM UE QR JP FS YH DA OW', 'hamming-distance': 5}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'OFN', 'plugboard': 'BX JE FR OP KS GA MN UW', 'hamming-distance': 6}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'PWI', 'plugboard': 'MC WV QP IS GH XA LN OB', 'hamming-distance': 6}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'PZK', 'plugboard': 'NT KE PR IS XH UA YB', 'hamming-distance': 5}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'QGG', 'plugboard': 'BV JE IR AU TS ZH LN', 'hamming-distance': 7}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'RSO', 'plugboard': 'DC RM VE FP GS NH UA OB QW', 'hamming-distance': 3}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'RFW', 'plugboard': 'HY BK VE OR XP US QA ZN LW', 'hamming-distance': 6}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'TOA', 'plugboard': 'ND WI VE TR QP JS UA LB', 'hamming-distance': 6}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'UKY', 'plugboard': 'HO LM YR ND JS XA GB VW', 'hamming-distance': 7}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'XGU', 'plugboard': 'IC KM GE DR TP BQ NH YA FW', 'hamming-distance': 4}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'YTQ', 'plugboard': 'BK UR WE VS GH XA DN', 'hamming-distance': 7}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'YVB', 'plugboard': 'LC OM FR ZP KS QH IA DB XW', 'hamming-distance': 3}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'YCP', 'plugboard': 'FC ZE YR AP JS OH XN IB QW', 'hamming-distance': 3}
# {'rotors': 'V IV III', 'ring-settings': 'A A A', 'display': 'ZIV', 'plugboard': 'LC GM OE NX KP HS YA QB FW', 'hamming-distance': 6}
# SEARCH FOR ENIGMA CONFIGURATIONS FINISHED
# number of possible configurations: 2073
# number of tried out configurations [per cycle]: [1014000]
# ------------------------------------------------------------------
# CHECKING ALL IDENTIFIED CONFIGURATIONS
# --invalid configuration : WEAIHERISCLEAR config_plugboard: LC ZM DE OR TP US XH JA YN IW
# --invalid configuration : WEAHHERISCLEAR config_plugboard: IC YE DR XP BS FH JA LW
# --invalid configuration : WEALHERISCLEAR config_plugboard: FC KM LE NR OS IH VA GW
# -----------------------------------------------------------------------------------------------------------
# FOUND SOLUTION! - decyphered text: WEATHERISCLEAR
# {'rotors': 'I II III', 'ring-settings': 'A A A', 'display': 'AAA', 'plugboard': 'CX DJ EI FT LS MR NZ OP QY UW', 'hamming-distance': 2}
# -----------------------------------------------------------------------------------------------------------

# %%
break_enigma("ODHKBI", "MONDAY")
# Out:
# CRIB:       MONDAY
# CYPHERTEXT: ODHKBI
# TURNOVERPROBABILITY: 23.08%
# TURING-BOMBE IS RUNNING...
# graph: {'A': ['B'], 'B': ['A'], 'C': [], 'D': ['O', 'K'], 'E': [], 'F': [], 'G': [], 'H': ['N'], 'I': ['Y'], 'J': [], 'K': ['D'], 'L': [], 'M': ['O'], 'N': ['H'], 'O': ['M', 'D'], 'P': [], 'Q': [], 'R': [], 'S': [], 'T': [], 'U': [], 'V': [], 'W': [], 'X': [], 'Y': ['I'], 'Z': []}
# Sorry, no loops in crib and cypher text found!

# %%
aaa = EnigmaMachine.from_key_sheet(
    rotors='I II III',
    reflector='B',
    ring_settings="A A A",
    #plugboard_settings='BN DR ES FT GZ HU IJ KO ML')
    plugboard_settings='EI FT MR UW')

aaa.set_display('HSP')
aaa.process_text('FQYNFJZQXMJTMIOWKABPLGM')
# Out:
# 'WWHKEWOMPISHTFLERMPMKAG'

# %%
from enigma.machine import EnigmaMachine

# setup machine according to specs from a daily key sheet:

machine = EnigmaMachine.from_key_sheet(
       rotors='I II III',
       reflector='B',
       ring_settings="A A A",
       plugboard_settings='QA WS')

# set machine initial starting position
machine.set_display('AAA')

# decrypt the message key
print(machine.process_text('AAA'))
# Out:
# CNV

# %% [markdown]
# __Tests für Ringstellungen__

# %%
m1 = EnigmaMachine.from_key_sheet(
       rotors='III II I',
       reflector='B',
       ring_settings="A A C",
       plugboard_settings='AW ES RD TF ZG UH IJ OK BN ML')

m2 = EnigmaMachine.from_key_sheet(
       rotors='III II I',
       reflector='B',
       ring_settings="A A A",
       plugboard_settings='AW ES RD TF ZG UH IJ OK BN ML')


m1.set_display('AAY')
print(m1.process_text('AAAAA'))
m2.set_display('AAW')
print(m2.process_text('AAAAA'))
# Out:
# HDXLN
# HDXLN
